# %%
import pandas as pd

# %%
C:\Users\Ratan Kumar Jha\Desktop\satyam_data\EESL_GENUS_PO0000000403_00000_SIM_Meter_Link_20231217_141005_SBPDCL.csv

# %%
data=pd.read_csv(r"C:\Users\Ratan Kumar Jha\Desktop\satyam_data\EESL_GENUS_PO0000000403_00000_SIM_Meter_Link_20231217_141005_SBPDCL.csv")

# %%
data.head()
# Out:
#                                                 data
# 0  GOEGP7426097;EP2PMeter;404751250004001;8991759...
# 1  GOEGP7433611;EP2PMeter;404751250004002;8991759...
# 2  GOEGP7427018;EP2PMeter;404751250004003;8991759...
# 3  GOEGP7448364;EP2PMeter;404751250004004;8991759...
# 4  GOEGP7436484;EP2PMeter;404751250004005;8991759...

# %%
import pandas as pd

import os,sys
from datetime import datetime

k=100
number=101

# Load your file into a pandas DataFrame
df = pd.read_csv(r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\EESL_GENUS_PO0000000403_00000_SIM_Meter_Link_20231217_141005_SBPDCL.csv', header=None)  # Replace 'your_input_file.csv' with your actual file name
output_location_1 = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\single_file_data_1'
output_location_2 = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\single_file_data_2'
output_location_3 = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\single_file_data_3'
output_location_4 = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\single_file_data_4'
output_location_5 = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\single_file_data_5'
output_location_6 = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\single_file_data_6'
output_location_7 = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\single_file_data_7'
output_location_8 = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\single_file_data_8'
output_location_9 = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\single_file_data_9'
output_location_10 = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\single_file_data_10'
output_location_11 = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\single_file_data_11'
output_location_12 = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\single_file_data_12'
output_location_13 = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\single_file_data_13'
output_location_14 = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\single_file_data_14'
output_location_15 = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\single_file_data_15'
output_location_16 = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\single_file_data_16'

def get_current_time_stamp():
    return f"{datetime.now().strftime('%Y-%m-%d %H-%M-%S')}"

CURRENT_TIME_STAMP = get_current_time_stamp()

# Iterate through each row and save it as a separate file
for index, row in df.iterrows():
    
    # Create a new DataFrame with the current row
    single_row_df = pd.DataFrame([row])

    CURRENT_TIME_STAMP = get_current_time_stamp()
    print(CURRENT_TIME_STAMP)
    k=k+1
    print(k)
    # Save the DataFrame to a file (you can choose a file format, e.g., CSV)
    
    
    
    if k< 900: 
        number=number+1
        file_name = f'EESL_GENUS_PO0000000{number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}.csv'
        file_path = os.path.join(output_location_1, file_name)
    #single_row_df.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\satyam_data\single_file_data\file_name", index=False, header=False) 
        single_row_df.to_csv(file_path, index=False, header=False)  

    elif k >901 and k < 1700:
        number=101
        number=number+1
        file_name = f'EESL_GENUS_PO0000000{number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}.csv'
        file_path = os.path.join(output_location_2, file_name)
        single_row_df.to_csv(file_path, index=False, header=False)  

    elif k >1702 and k < 2500:
        number=101
        number=number+1
        file_name = f'EESL_GENUS_PO0000000{number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}.csv'
        file_path = os.path.join(output_location_3, file_name)
        single_row_df.to_csv(file_path, index=False, header=False) 

    elif k >2502 and k < 3300:
        number=101
        number=number+1
        file_name = f'EESL_GENUS_PO0000000{number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}.csv'
        file_path = os.path.join(output_location_4, file_name)
        single_row_df.to_csv(file_path, index=False, header=False) 

    elif k >3302 and k < 4100:
        number=101
        number=number+1
        file_name = f'EESL_GENUS_PO0000000{number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}.csv'
        file_path = os.path.join(output_location_5, file_name)
        single_row_df.to_csv(file_path, index=False, header=False) 

    elif k >4102 and k < 4900:
        number=101
        number=number+1
        file_name = f'EESL_GENUS_PO0000000{number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}.csv'
        file_path = os.path.join(output_location_6, file_name)
        single_row_df.to_csv(file_path, index=False, header=False) 

    elif k >4902 and k < 5700:
        number=101
        number=number+1
        file_name = f'EESL_GENUS_PO0000000{number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}.csv'
        file_path = os.path.join(output_location_7, file_name)
        single_row_df.to_csv(file_path, index=False, header=False) 

    elif k >5702 and k < 6500:
        number=101
        number=number+1
        file_name = f'EESL_GENUS_PO0000000{number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}.csv'
        file_path = os.path.join(output_location_8, file_name)
        single_row_df.to_csv(file_path, index=False, header=False) 

    elif k >6502 and k < 7300:
        number=101
        number=number+1
        file_name = f'EESL_GENUS_PO0000000{number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}.csv'
        file_path = os.path.join(output_location_9, file_name)
        single_row_df.to_csv(file_path, index=False, header=False) 

    elif k >7302 and k < 8000:
        number=101
        number=number+1
        file_name = f'EESL_GENUS_PO0000000{number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}.csv'
        file_path = os.path.join(output_location_10, file_name)
        single_row_df.to_csv(file_path, index=False, header=False) 

    elif k >8002 and k < 8900:
        number=101
        number=number+1
        file_name = f'EESL_GENUS_PO0000000{number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}.csv'
        file_path = os.path.join(output_location_11, file_name)
        single_row_df.to_csv(file_path, index=False, header=False)
# Out:
# 2023-12-20 15-27-18
# 101
# 2023-12-20 15-27-18
# 102
# 2023-12-20 15-27-18
# 103
# 2023-12-20 15-27-18
# 104
# 2023-12-20 15-27-18
# 105
# 2023-12-20 15-27-18
# 106
# 2023-12-20 15-27-18
# 107
# 2023-12-20 15-27-18
# 108
# 2023-12-20 15-27-18
# 109
# 2023-12-20 15-27-18
# 110
# 2023-12-20 15-27-18
# 111
# 2023-12-20 15-27-18
# 112
# 2023-12-20 15-27-18
# 113
# 2023-12-20 15-27-18
# 114
# 2023-12-20 15-27-18
# 115
# 2023-12-20 15-27-18
# 116
# 2023-12-20 15-27-18
# 117
# 2023-12-20 15-27-18
# 118
# 2023-12-20 15-27-18
# 119
# 2023-12-20 15-27-18
# 120
# 2023-12-20 15-27-18
# 121
# 2023-12-20 15-27-18
# 122
# 2023-12-20 15-27-18
# 123
# 2023-12-20 15-27-18
# 124
# 2023-12-20 15-27-18
# 125
# 2023-12-20 15-27-18
# 126
# 2023-12-20 15-27-18
# 127
# 2023-12-20 15-27-18
# 128
# 2023-12-20 15-27-18
# 129
# 2023-12-20 15-27-18
# 130
# 2023-12-20 15-27-18
# 131
# 2023-12-20 15-27-18
# 132
# 2023-12-20 15-27-18
# 133
# 2023-12-20 15-27-18
# 134
# 2023-12-20 15-27-18
# 135
# ...

# %%
from datetime import datetime
def get_current_time_stamp():
    return f"{datetime.now().strftime('%Y-%m-%d %H-%M-%S')}"

CURRENT_TIME_STAMP = get_current_time_stamp()
print(CURRENT_TIME_STAMP)
# Out:
# 2023-12-20 14-47-07

# %%
import pandas as pd
import os
from datetime import datetime

# Load your file into a pandas DataFrame
df = pd.read_csv('your_input_file.csv', header=None)  # Replace 'your_input_file.csv' with your actual file name

# Specify the output location
output_location = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\single_file_data'

# Iterate through each row and save it as a separate file
for index, row in df.iterrows():
    # Create a new DataFrame with the current row
    single_row_df = pd.DataFrame([row])
    
    # Create the output file name
    current_time_stamp = datetime.now().strftime('%Y%m%d%H%M%S')
    file_name = f'EESL_GENUS_PO0000000{index}_00000_SIM_Meter_Link_{current_time_stamp}.csv'
    
    # Create the full path for saving the file
    file_path = os.path.join(output_location, file_name)
    
    # Save the DataFrame to the specified location
    single_row_df.to_csv(file_path, index=False, header=False)  # Set header=False to omit the column header

# %%
C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file

# %%
import os

# Specify the path of the folder
folder_path = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\single_file_data'

# List all files in the folder
file_list = os.listdir(folder_path)
print(file_list)

# Iterate through each file and perform your operations
for file_name in file_list:
    # Create the full path for the file
    file_path = os.path.join(folder_path, file_name)
    print(file_path)
    break
    
    # Check if the item is a file (not a subdirectory)
    if os.path.isfile(file_path):
        # Open and read the file (perform your operations here)
        with open(file_path, 'r') as file:
            content = file.read()
            # Do something with the content (e.g., print it)
            print(f"Content of file {file_name}:\n{content}")

        # If you want to process the content as a DataFrame (assuming CSV)
        # df = pd.read_csv(file_path)
        # Do something with the DataFrame
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 7
#       4 folder_path = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\single_file_data'
#       6 # List all files in the folder
# ----> 7 file_list = os.listdir(folder_path)
#       8 print(file_list)
#      10 # Iterate through each file and perform your operations
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\Ratan Kumar Jha\\Desktop\\satyam_data\\single_file_data'

# %% [markdown]
# # working file

# %%
import pandas as pd

import os,sys
from datetime import datetime

k=100


# Load your file into a pandas DataFrame
df = pd.read_csv(r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\EESL_GENUS_PO0000000102_00000_SIM_Meter_Link_20231216_144442_SBPDCL.csv', header=None)  # Replace 'your_input_file.csv' with your actual file name


output_location_1 = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\single_file_data_1'

def get_current_time_stamp():
    return f"{datetime.now().strftime('%Y%m%d_%H%M%S')}"

CURRENT_TIME_STAMP = get_current_time_stamp()

# Iterate through each row and save it as a separate file
for index, row in df.iterrows():
    
    # Create a new DataFrame with the current row
    single_row_df = pd.DataFrame([row])

    CURRENT_TIME_STAMP = get_current_time_stamp()
    print(CURRENT_TIME_STAMP)
    k=k+1
    print(k)
    # Save the DataFrame to a file (you can choose a file format, e.g., CSV)
    
    file_name = f'EESL_GENUS_PO0000000{k}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}.csv'
    file_path = os.path.join(output_location_1, file_name)
    #single_row_df.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\satyam_data\single_file_data\file_name", index=False, header=False) 
    single_row_df.to_csv(file_path, index=False, header=False)
# Out:
# 20231220_160004
# 101
# 20231220_160004
# 102
# 20231220_160004
# 103
# 20231220_160004
# 104
# 20231220_160004
# 105
# 20231220_160004
# 106
# 20231220_160004
# 107
# 20231220_160004
# 108
# 20231220_160004
# 109
# 20231220_160004
# 110
# 20231220_160004
# 111
# 20231220_160004
# 112
# 20231220_160004
# 113
# 20231220_160004
# 114
# 20231220_160004
# 115
# 20231220_160004
# 116
# 20231220_160004
# 117
# 20231220_160004
# 118
# 20231220_160004
# 119
# 20231220_160004
# 120
# 20231220_160004
# 121
# 20231220_160004
# 122
# 20231220_160004
# 123
# 20231220_160004
# 124
# 20231220_160004
# 125
# 20231220_160004
# 126
# 20231220_160004
# 127
# 20231220_160004
# 128
# 20231220_160004
# 129
# 20231220_160004
# 130
# 20231220_160004
# 131
# 20231220_160004
# 132
# 20231220_160004
# 133
# 20231220_160005
# 134
# 20231220_160005
# 135
# 20231220_160005
# 136
# 20231220_160005
# 137
# 20231220_160005
# 138
# 20231220_160005
# 139
# 20231220_160005
# 140
# 20231220_160005
# 141
# ...

# %% [markdown]
# # working on this file.

# %% [markdown]
# # code is ready but need to implement OOPS

# %%
import pandas as pd

import os,sys
from datetime import datetime

k=100


# Load your file into a pandas DataFrame
df = pd.read_csv(r'C:\Users\Ratan Kumar Jha\Desktop\EESL_GENUS_PO0000000\EESL_GENUS_PO0000000403_00000_SIM_Meter_Link_20231217_141005_SBPDCL.csv', header=None)  # Replace 'your_input_file.csv' with your actual file name

base_path = r'C:\Users\Ratan Kumar Jha\Desktop\EESL_GENUS_PO0000000\data_insert_single_file'
#new_folder_name = 'letscheck'
#output_location= r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\single_file_data_1'


#folder location
new_folder_name = 'letscheck'
new_folder_name_1 = 'letscheck_1'
new_folder_name_2 = 'letscheck_2'
new_folder_name_3 = 'letscheck_3'
new_folder_name_4 = 'letscheck_4'
new_folder_name_5 = 'letscheck_5'
new_folder_name_6 = 'letscheck_6'
new_folder_name_7 = 'letscheck_7'
new_folder_name_8 = 'letscheck_8'
new_folder_name_9 = 'letscheck_9'
new_folder_name_10 = 'letscheck_10'
new_folder_name_11 = 'letscheck_11'
new_folder_name_12 = 'letscheck_12'
new_folder_name_13 = 'letscheck_13'
new_folder_name_14 = 'letscheck_14'
new_folder_name_15 = 'letscheck_15'

#3 digit number

three_digit_number = 100


def get_current_time_stamp():
    return f"{datetime.now().strftime('%Y%m%d_%H%M%S')}"

CURRENT_TIME_STAMP = get_current_time_stamp()

# Iterate through each row and save it as a separate file
for index, row in df.iterrows():
    
    # Create a new DataFrame with the current row
    single_row_df = pd.DataFrame([row])

    CURRENT_TIME_STAMP = get_current_time_stamp()
    print(CURRENT_TIME_STAMP)
    k=k+1
    print(k)
    print("-----------------")
    
    
    if k < 1000:
        # Create the full path for the new folder

        new_folder_path = os.path.join(base_path, new_folder_name)
        # Check if the folder already exists
        if  os.path.exists(new_folder_path):
            # Create the new folder
            #os.makedirs(new_folder_path)
            
            file_name = f'EESL_GENUS_PO0000000{k}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}_SBPDCL.csv'
            file_path = os.path.join(new_folder_path, file_name)
            #single_row_df.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\satyam_data\single_file_data\file_name", index=False, header=False) 
            single_row_df.to_csv(file_path, index=False, header=False)
        else:
            #new_folder_name= input("enter the file name")
            os.makedirs(new_folder_path)

    elif k < 1900:
        # Create the full path for the new folder

        new_folder_path = os.path.join(base_path, new_folder_name_1)
        # Check if the folder already exists
        if  os.path.exists(new_folder_path):
            # Create the new folder
            #os.makedirs(new_folder_path)
            
            file_name = f'EESL_GENUS_PO0000000{three_digit_number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}_SBPDCL.csv'
            file_path = os.path.join(new_folder_path, file_name)
            #single_row_df.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\satyam_data\single_file_data\file_name", index=False, header=False) 
            single_row_df.to_csv(file_path, index=False, header=False)

            # 3 digit no.
            three_digit_number=three_digit_number+1
            
        else:
            #new_folder_name= input("enter the file name")
            os.makedirs(new_folder_path)
    
    elif k < 2800:
        # Create the full path for the new folder

        new_folder_path = os.path.join(base_path, new_folder_name_2)
        # Check if the folder already exists
        if  os.path.exists(new_folder_path):
            # Create the new folder
            #os.makedirs(new_folder_path)
            file_name = f'EESL_GENUS_PO0000000{three_digit_number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}_SBPDCL.csv'
            file_path = os.path.join(new_folder_path, file_name)
            #single_row_df.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\satyam_data\single_file_data\file_name", index=False, header=False) 
            single_row_df.to_csv(file_path, index=False, header=False)

            # 3 digit no.
            three_digit_number=three_digit_number+1

        else:
            #new_folder_name= input("enter the file name")
            os.makedirs(new_folder_path)
            three_digit_number=100



    elif k < 3700:
        # Create the full path for the new folder

        new_folder_path = os.path.join(base_path, new_folder_name_3)
        # Check if the folder already exists
        if  os.path.exists(new_folder_path):
            # Create the new folder
            #os.makedirs(new_folder_path)
            file_name = f'EESL_GENUS_PO0000000{three_digit_number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}_SBPDCL.csv'
            file_path = os.path.join(new_folder_path, file_name)
            #single_row_df.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\satyam_data\single_file_data\file_name", index=False, header=False) 
            single_row_df.to_csv(file_path, index=False, header=False)

            # 3 digit no.
            three_digit_number=three_digit_number+1
        else:
            #new_folder_name= input("enter the file name")
            os.makedirs(new_folder_path)
            three_digit_number=100

    elif k < 4600:
        # Create the full path for the new folder

        new_folder_path = os.path.join(base_path, new_folder_name_4)
        # Check if the folder already exists
        if  os.path.exists(new_folder_path):
            # Create the new folder
            #os.makedirs(new_folder_path)
            file_name = f'EESL_GENUS_PO0000000{three_digit_number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}_SBPDCL.csv'
            file_path = os.path.join(new_folder_path, file_name)
            #single_row_df.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\satyam_data\single_file_data\file_name", index=False, header=False) 
            single_row_df.to_csv(file_path, index=False, header=False)

            # 3 digit no.
            three_digit_number=three_digit_number+1
        else:
            #new_folder_name= input("enter the file name")
            os.makedirs(new_folder_path)
            three_digit_number=100


    elif k < 5500:
        # Create the full path for the new folder

        new_folder_path = os.path.join(base_path, new_folder_name_5)
        # Check if the folder already exists
        if  os.path.exists(new_folder_path):
            # Create the new folder
            #os.makedirs(new_folder_path)
            file_name = f'EESL_GENUS_PO0000000{three_digit_number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}_SBPDCL.csv'
            file_path = os.path.join(new_folder_path, file_name)
            #single_row_df.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\satyam_data\single_file_data\file_name", index=False, header=False) 
            single_row_df.to_csv(file_path, index=False, header=False)

            # 3 digit no.
            three_digit_number=three_digit_number+1
        else:
            #new_folder_name= input("enter the file name")
            os.makedirs(new_folder_path)
            three_digit_number=100


    elif k < 6400:
        # Create the full path for the new folder

        new_folder_path = os.path.join(base_path, new_folder_name_6)
        # Check if the folder already exists
        if  os.path.exists(new_folder_path):
            # Create the new folder
            #os.makedirs(new_folder_path)
            file_name = f'EESL_GENUS_PO0000000{three_digit_number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}_SBPDCL.csv'
            file_path = os.path.join(new_folder_path, file_name)
            #single_row_df.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\satyam_data\single_file_data\file_name", index=False, header=False) 
            single_row_df.to_csv(file_path, index=False, header=False)

            # 3 digit no.
            three_digit_number=three_digit_number+1
        else:
            #new_folder_name= input("enter the file name")
            os.makedirs(new_folder_path)
            three_digit_number=100


    elif k < 7500:
        # Create the full path for the new folder

        new_folder_path = os.path.join(base_path, new_folder_name_7)
        # Check if the folder already exists
        if  os.path.exists(new_folder_path):
            # Create the new folder
            #os.makedirs(new_folder_path)
            file_name = f'EESL_GENUS_PO0000000{three_digit_number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}_SBPDCL.csv'
            file_path = os.path.join(new_folder_path, file_name)
            #single_row_df.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\satyam_data\single_file_data\file_name", index=False, header=False) 
            single_row_df.to_csv(file_path, index=False, header=False)

            # 3 digit no.
            three_digit_number=three_digit_number+1
        else:
            #new_folder_name= input("enter the file name")
            os.makedirs(new_folder_path)
            three_digit_number=100


    elif k < 8400:
        # Create the full path for the new folder

        new_folder_path = os.path.join(base_path, new_folder_name_8)
        # Check if the folder already exists
        if  os.path.exists(new_folder_path):
            # Create the new folder
            #os.makedirs(new_folder_path)
            file_name = f'EESL_GENUS_PO0000000{three_digit_number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}_SBPDCL.csv'
            file_path = os.path.join(new_folder_path, file_name)
            #single_row_df.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\satyam_data\single_file_data\file_name", index=False, header=False) 
            single_row_df.to_csv(file_path, index=False, header=False)

            # 3 digit no.
            three_digit_number=three_digit_number+1
        else:
            #new_folder_name= input("enter the file name")
            os.makedirs(new_folder_path)
            three_digit_number=100


    elif k < 9300:
        # Create the full path for the new folder

        new_folder_path = os.path.join(base_path, new_folder_name_9)
        # Check if the folder already exists
        if  os.path.exists(new_folder_path):
            # Create the new folder
            #os.makedirs(new_folder_path)
            file_name = f'EESL_GENUS_PO0000000{three_digit_number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}_SBPDCL.csv'
            file_path = os.path.join(new_folder_path, file_name)
            #single_row_df.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\satyam_data\single_file_data\file_name", index=False, header=False) 
            single_row_df.to_csv(file_path, index=False, header=False)

            # 3 digit no.
            three_digit_number=three_digit_number+1
        else:
            #new_folder_name= input("enter the file name")
            os.makedirs(new_folder_path)
            three_digit_number=100


    elif k < 10200:
        # Create the full path for the new folder

        new_folder_path = os.path.join(base_path, new_folder_name_10)
        # Check if the folder already exists
        if  os.path.exists(new_folder_path):
            # Create the new folder
            #os.makedirs(new_folder_path)
            file_name = f'EESL_GENUS_PO0000000{three_digit_number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}_SBPDCL.csv'
            file_path = os.path.join(new_folder_path, file_name)
            #single_row_df.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\satyam_data\single_file_data\file_name", index=False, header=False) 
            single_row_df.to_csv(file_path, index=False, header=False)

            # 3 digit no.
            three_digit_number=three_digit_number+1
        else:
            #new_folder_name= input("enter the file name")
            os.makedirs(new_folder_path)
            three_digit_number=100


    elif k < 1100:
        # Create the full path for the new folder

        new_folder_path = os.path.join(base_path, new_folder_name_11)
        # Check if the folder already exists
        if  os.path.exists(new_folder_path):
            # Create the new folder
            #os.makedirs(new_folder_path)
            file_name = f'EESL_GENUS_PO0000000{three_digit_number}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}_SBPDCL.csv'
            file_path = os.path.join(new_folder_path, file_name)
            #single_row_df.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\satyam_data\single_file_data\file_name", index=False, header=False) 
            single_row_df.to_csv(file_path, index=False, header=False)

            # 3 digit no.
            three_digit_number=three_digit_number+1
        else:
            #new_folder_name= input("enter the file name")
            os.makedirs(new_folder_path)
            three_digit_number=100

    else:
        break
# Out:
# 20231220_180636
# 101
# -----------------
# 20231220_180636
# 102
# -----------------
# 20231220_180636
# 103
# -----------------
# 20231220_180636
# 104
# -----------------
# 20231220_180636
# 105
# -----------------
# 20231220_180636
# 106
# -----------------
# 20231220_180636
# 107
# -----------------
# 20231220_180636
# 108
# -----------------
# 20231220_180636
# 109
# -----------------
# 20231220_180636
# 110
# -----------------
# 20231220_180637
# 111
# -----------------
# 20231220_180637
# 112
# -----------------
# 20231220_180637
# 113
# -----------------
# 20231220_180637
# 114
# -----------------
# 20231220_180637
# 115
# -----------------
# 20231220_180637
# 116
# -----------------
# 20231220_180637
# 117
# -----------------
# 20231220_180637
# 118
# -----------------
# 20231220_180637
# 119
# -----------------
# 20231220_180637
# 120
# -----------------
# 20231220_180637
# 121
# -----------------
# 20231220_180637
# 122
# -----------------
# 20231220_180637
# 123
# ...

# %%
import os

# Specify the path for the new folder
base_path = r'C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file'
new_folder_name = 'x'

# Define the value of k
k = 150  # Replace with your actual value of k

# Check if k is greater than 100
if k > 100:
    # Create the full path for the new folder
    new_folder_path = os.path.join(base_path, new_folder_name)

    # Check if the folder already exists
    if not os.path.exists(new_folder_path):
        # Create the new folder
        os.makedirs(new_folder_path)
        print(f"Folder '{new_folder_name}' created at {new_folder_path}")
    else:
        print(f"Folder '{new_folder_name}' already exists at {new_folder_path}")
else:
    print("Value of k is not greater than 100.")
# Out:
# Folder 'x' created at C:\Users\Ratan Kumar Jha\Desktop\satyam_data\data_insert_single_file\x

# %% [markdown]
# # this code is working, short and crispy

# %%
import pandas as pd

import os,sys
from datetime import datetime

k=100
# Load your file into a pandas DataFrame
df = pd.read_csv(r'C:\Users\Ratan Kumar Jha\Desktop\EESL_GENUS_PO0000000\EESL_GENUS_PO0000000498_00000_SIM_Meter_Link_20240213_173000_SBPDCL.csv', header=None)  # Replace 'your_input_file.csv' with your actual file name

base_path = r'C:\Users\Ratan Kumar Jha\Desktop\EESL_GENUS_PO0000000\data_insert_single_file'

num_folder = 0
new_folder_name = "letstest"

new_folder_path = os.path.join(base_path, new_folder_name)
os.makedirs(new_folder_path)

def get_current_time_stamp():
    return f"{datetime.now().strftime('%Y%m%d_%H%M%S')}"

CURRENT_TIME_STAMP = get_current_time_stamp()

# Iterate through each row and save it as a separate file
for index, row in df.iterrows():
    
    # Create a new DataFrame with the current row
    single_row_df = pd.DataFrame([row])

    CURRENT_TIME_STAMP = get_current_time_stamp()
    print(CURRENT_TIME_STAMP)
    
    print(k)
    print("-----------------")
    
    # Create the full path for the new folder

    if k > 995:
        k = 100
        num_folder = num_folder + 1
        new_folder_name = "letstest_" + str(num_folder)
        new_folder_path = os.path.join(base_path, new_folder_name)
        os.makedirs(new_folder_path)
    else:
        file_name = f'EESL_GENUS_PO0000000{k}_00000_SIM_Meter_Link_{CURRENT_TIME_STAMP}_SBPDCL.csv'
        file_path = os.path.join(new_folder_path, file_name)
        #single_row_df.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\satyam_data\single_file_data\file_name", index=False, header=False) 
        single_row_df.to_csv(file_path, index=False, header=False)
        k=k+1
# Out:
# 20240215_130203
# 100
# -----------------
# 20240215_130203
# 101
# -----------------
# 20240215_130203
# 102
# -----------------
# 20240215_130203
# 103
# -----------------
# 20240215_130203
# 104
# -----------------
# 20240215_130203
# 105
# -----------------
# 20240215_130203
# 106
# -----------------
# 20240215_130203
# 107
# -----------------
# 20240215_130203
# 108
# -----------------
# 20240215_130203
# 109
# -----------------
# 20240215_130203
# 110
# -----------------
# 20240215_130203
# 111
# -----------------
# 20240215_130203
# 112
# -----------------
# 20240215_130203
# 113
# -----------------
# 20240215_130203
# 114
# -----------------
# 20240215_130203
# 115
# -----------------
# 20240215_130203
# 116
# -----------------
# 20240215_130203
# 117
# -----------------
# 20240215_130203
# 118
# -----------------
# 20240215_130203
# 119
# -----------------
# 20240215_130203
# 120
# -----------------
# 20240215_130203
# 121
# -----------------
